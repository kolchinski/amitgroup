# %%
import digit_features as df
import numpy as np
import amitgroup as ag
import SeqKMeans as skm
#import matplotlib
#matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi']

# %%
skm1 = skm.SeqKMeans(df.flatPixelTrainData(),10)
skm1.trainMeans()
# Out:
# Points per cluster:  [   1.  200.  379.   55.   75.    1.   18.   38.   77.  156.]

# %%
# %run pegasos.py
# Out:
# Training one-vs-rest SVM for class 0
# Total loss: 0.0997576361817
# Total loss: 0.0859551000711
# Total loss: 0.0499893822225
# Total loss: 0.0714400736146
# Total loss: 0.0415107486007
# Total loss: 0.0422373603794
# Total loss: 0.0483713879386
# Total loss: 0.0377986740757
# Total loss: 0.0421753963524
# Total loss: 0.0381679807931
# Training one-vs-rest SVM for class 1
# Total loss: 0.0798370754692
# Total loss: 0.0857029825315
# Total loss: 0.0587060390563
# Total loss: 0.0602651687633
# Total loss: 0.0484624719537
# Total loss: 0.0479098278063
# Total loss: 0.0520688512371
# Total loss: 0.0451991911534
# Total loss: 0.0436823556861
# Total loss: 0.0452679441543
# Training one-vs-rest SVM for class 2
# Total loss: 0.141260416785
# Total loss: 0.176387137333
# Total loss: 0.0833120601317
# Total loss: 0.0695307085297
# Total loss: 0.0660662529541
# Total loss: 0.0615845232114
# Total loss: 0.0750214096874
# Total loss: 0.061693121576
# Total loss: 0.064271140172
# ...
